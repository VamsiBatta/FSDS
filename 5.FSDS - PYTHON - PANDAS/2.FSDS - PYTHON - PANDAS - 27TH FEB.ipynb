# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1['Player']
# Out:
# 0          Quincy Acy
# 1        Jordan Adams
# 2        Steven Adams
# 3         Jeff Adrien
# 4       Arron Afflalo
#             ...
# 670    Thaddeus Young
# 671    Thaddeus Young
# 672    Thaddeus Young
# 673       Cody Zeller
# 674      Tyler Zeller
# Name: Player, Length: 675, dtype: object

# %%
df1['Player'].dtype
# Out:
# dtype('O')

# %%
type(df1['Player'])
# Out:
# pandas.core.series.Series

# %%
df1[['Player', 'Age']]
# Out:
#              Player Age
# 0        Quincy Acy  24
# 1      Jordan Adams  20
# 2      Steven Adams  21
# 3       Jeff Adrien  28
# 4     Arron Afflalo  29
# ..              ...  ..
# 670  Thaddeus Young  26
# 671  Thaddeus Young  26
# 672  Thaddeus Young  26
# 673     Cody Zeller  22
# 674    Tyler Zeller  25
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F832-2B0D
#
#  Directory of C:\Users\bvams\Documents\FSDS\FSDS - PYTHON - PANDAS
#
# 08/24/2022  03:40 PM    <DIR>          .
# 08/23/2022  03:35 PM    <DIR>          ..
# 08/24/2022  03:03 PM    <DIR>          .ipynb_checkpoints
# 08/23/2022  03:55 PM             1,173 addresses.csv
# 08/23/2022  03:55 PM             1,589 contacts.csv
# 08/24/2022  12:06 PM           395,961 FSDS - PYTHON - PANDAS - 26TH FEB.ipynb
# 08/24/2022  03:39 PM            34,798 FSDS - PYTHON - PANDAS - 27TH FEB.ipynb
# 08/23/2022  03:55 PM               277 holiday_schedules.csv
# 08/23/2022  03:55 PM            18,015 locations.csv
# 08/23/2022  06:29 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 08/23/2022  06:29 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# ...

# %%
pd.read_csv("NBA.csv")
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1      Quincy Acy  PF  24  NYK  68  22  1287  152  ...
# 1             1    2    Jordan Adams  SG  20  MEM  30   0   248   35  ...
# 2             2    3    Steven Adams   C  21  OKC  70  67  1771  217  ...
# 3             3    4     Jeff Adrien  PF  28  MIN  17   0   215   19  ...
# 4             4    5   Arron Afflalo  SG  29  TOT  78  72  2502  375  ...
# ..          ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# ...

# %%
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df1.to_csv('NBA.csv', index=False)

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F832-2B0D
#
#  Directory of C:\Users\bvams\Documents\FSDS\FSDS - PYTHON - PANDAS
#
# 08/24/2022  03:43 PM    <DIR>          .
# 08/23/2022  03:35 PM    <DIR>          ..
# 08/24/2022  03:03 PM    <DIR>          .ipynb_checkpoints
# 08/23/2022  03:55 PM             1,173 addresses.csv
# 08/23/2022  03:55 PM             1,589 contacts.csv
# 08/24/2022  12:06 PM           395,961 FSDS - PYTHON - PANDAS - 26TH FEB.ipynb
# 08/24/2022  03:43 PM            72,157 FSDS - PYTHON - PANDAS - 27TH FEB.ipynb
# 08/23/2022  03:55 PM               277 holiday_schedules.csv
# 08/23/2022  03:55 PM            18,015 locations.csv
# 08/23/2022  06:29 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 08/23/2022  06:29 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# ...

# %%
df2=pd.read_html("https://www.skysports.com/cricket/tables")

# %%
len(df2)
# Out:
# 14

# %%
df2[0]
# Out:
#    POS              TEAM  PLD  W  D  L  PTS
# 0    1            Surrey   11  7  4  0  209
# 1    2         Hampshire   11  8  1  2  193
# 2    3        Lancashire   11  5  5  1  175
# 3    4             Essex   10  4  4  2  135
# 4    5  Northamptonshire   10  2  6  2  130

# %%
df2[1]
# Out:
#    POS             TEAM  PLD  W  D  L  PTS
# 0    1  Nottinghamshire   11  6  4  1  195
# 1    2        Middlesex   11  4  5  2  165
# 2    3        Glamorgan   10  5  3  2  160
# 3    4       Derbyshire   11  3  6  2  155
# 4    5   Worcestershire   10  3  4  3  130

# %%
df2[2]
# Out:
#    POS                  TEAM  PLD  W  D  L  PTS
# 0    1         Trent Rockets    6  5  0  1   10
# 1    2         London Spirit    5  4  0  1    8
# 2    3    Birmingham Phoenix    6  4  0  2    8
# 3    4  Manchester Originals    6  3  0  3    6
# 4    5      Oval Invincibles    6  3  0  3    6

# %%
df2[2]
# Out:
#    POS                  TEAM  PLD  W  D  L  PTS
# 0    1         Trent Rockets    6  5  0  1   10
# 1    2         London Spirit    5  4  0  1    8
# 2    3    Birmingham Phoenix    6  4  0  2    8
# 3    4  Manchester Originals    6  3  0  3    6
# 4    5      Oval Invincibles    6  3  0  3    6

# %%
df2[0].to_csv('Cricket_Group_1.csv', index = False)

# %%
d = """
{
    "name":"Vamsi B",
    "Email-ID": "vamsi@gmail.com",
    "Tech":["Python", "SQL", "Java", "MongoDB"],
    "platform":["Abcd", "Xyz"]
}
"""

# %%
import json

# %% [raw]
# json - javascript object notation

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'Vamsi B',
#  'Email-ID': 'vamsi@gmail.com',
#  'Tech': ['Python', 'SQL', 'Java', 'MongoDB'],
#  'platform': ['Abcd', 'Xyz']}

# %%
type(result)
# Out:
# dict

# %%
type(d)
# Out:
# str

# %%
pd.DataFrame(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 pd.DataFrame(result)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
# ...

# %%
d1 = """
{
    "name":"Vamsi B",
    "Email-ID": "vamsi@gmail.com",
    "Tech":["Python", "SQL"],
    "platform":["Abcd", "Xyz"]
}
"""

# %%
result1 = json.loads(d1)

# %%
pd.DataFrame(result1)
# Out:
#       name         Email-ID    Tech platform
# 0  Vamsi B  vamsi@gmail.com  Python     Abcd
# 1  Vamsi B  vamsi@gmail.com     SQL      Xyz

# %%
pd.DataFrame(result1['Tech'])
# Out:
#         0
# 0  Python
# 1     SQL

# %%
type(pd.DataFrame(result1['Tech']))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests

# %%
data = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48265',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48265/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48265/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48265/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48265',
#   'id': 1351762150,
#   'node_id': 'PR_kwDOAA0YD84911Iy',
#   'number': 48265,
#   'title': 'CI: Setting up ssh key to upload prod docs',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
# ...

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 39504233
# 5146641
# 36619387
# 10971788
# 10971788
# 10647082
# 33491632
# 25160953
# 1020496
# 10058240
# 9309570
# 31857876
# 10647082
# 10647082
# 97266896
# 61934744
# 86249255
# 36619387
# 6618166
# 61934744
# 37621491
# 6618166
# 61934744
# 8174342
# 6299642
# 61934744
# 61934744
# 10647082
# 8078968
# 10647082

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48228',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48228/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48228/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48228/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48228',
#   'id': 1349585725,
#   'node_id': 'PR_kwDOAA0YD849uhch',
#   'number': 48228,
#   'title': 'Backport PR #48197 on branch 1.5.x (DOC: Cleanup 1.5 whatsnew)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
# ...

# %%
df4 = pd.DataFrame(data1, columns= ['id','user','url', 'repository_url', 'labels_url','reactions'])

# %%
df4.to_csv("json_response.csv")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F832-2B0D
#
#  Directory of C:\Users\bvams\Documents\FSDS\FSDS - PYTHON - PANDAS
#
# 08/24/2022  10:04 PM    <DIR>          .
# 08/23/2022  03:35 PM    <DIR>          ..
# 08/24/2022  03:03 PM    <DIR>          .ipynb_checkpoints
# 08/23/2022  03:55 PM             1,173 addresses.csv
# 08/23/2022  03:55 PM             1,589 contacts.csv
# 08/24/2022  04:12 PM               155 Cricket_Group_1.csv
# 08/24/2022  12:06 PM           395,961 FSDS - PYTHON - PANDAS - 26TH FEB.ipynb
# 08/24/2022  10:01 PM           519,344 FSDS - PYTHON - PANDAS - 27TH FEB.ipynb
# 08/23/2022  03:55 PM               277 holiday_schedules.csv
# 08/24/2022  10:04 PM            40,432 json_response.csv
# 08/23/2022  03:55 PM            18,015 locations.csv
# 08/23/2022  06:29 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# ...

# %%
df5 = pd.read_csv("json_response.csv")

# %%
df5
# Out:
#     Unnamed: 0          id                                               user  \
# 0            0  1351762150  {'login': 'datapythonista', 'id': 10058240, 'n...
# 1            1  1351663731  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 2            2  1351559320  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3            3  1351539785  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 4            4  1351505437  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 5            5  1351455222  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6            6  1351308018  {'login': 'chalmerlowe', 'id': 7291104, 'node_...
# 7            7  1351294894  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 8            8  1351237349  {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 9            9  1351188794  {'login': 'pyrito', 'id': 8106509, 'node_id': ...
# 10          10  1351023955  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# ...

# %%
import json

dfs = pd.concat([(pd.json_normalize(json.loads(d))) for d in df4["user"]])
dfs = pd.DataFrame(dfs.values, columns=dfs.columns, index=df.index)

df = pd.concat([df, dfs], axis=1)
df.pop("user")
print(df.to_markdown())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 import json
# ----> 3 dfs = pd.concat([(pd.json_normalize(json.loads(d))) for d in df4["user"]])
#       4 dfs = pd.DataFrame(dfs.values, columns=dfs.columns, index=df.index)
#       6 df = pd.concat([df, dfs], axis=1)
#
# Input In [22], in <listcomp>(.0)
#       1 import json
# ----> 3 dfs = pd.concat([(pd.json_normalize(json.loads(d))) for d in df4["user"]])
#       4 dfs = pd.DataFrame(dfs.values, columns=dfs.columns, index=df.index)
#       6 df = pd.concat([df, dfs], axis=1)
#
# File ~\anaconda3\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# ...
