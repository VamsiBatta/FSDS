# %%
from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
task_url = "https://www.getketch.com/category/men.html"

# %%
task_url
# Out:
# 'https://www.getketch.com/category/men.html'

# %%
uClient = uReq(task_url)

# %%
uClient

# %%
task_page = uClient.read()

# %%
task_page
# Out:
# b'<!doctype html>\n<html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D">\n<img width="99988" height="99998" class="largestImage" style="pointer-events:none;position:absolute;top:0;left:0;width:98vw;height:99vh;max-width:98vw;max-height:99vh" src="data:image/svg+xml;base64,...">\n  <head >\n    <title>Buy Menswear Online - Best Clothes for Men at Great Prices | Ketch</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1"><meta data-n-head="ssr" data-hid="google-site-verification" name="google-site-verification" content="wzAPa91eToo-NpF8ic1jV249YZTrezrGXMqVw6GEKKo"><meta data-n-head="ssr" data-hid="facebook-domain-verification" name="facebook-domain-verification" content="w117cyuk8cf8u0rk5iuwjd2l16orgc"><meta data-n-head="ssr" name="description" content="Shop best clothes for men online from the best clothing brands for men at Ketch. \xe2\x9c\x94Buy Men&#x27;s Clothing Onlin
# ...

# %%
uClient.close()

# %%
task_html = bs(task_page, "html.parser")

# %%
task_html
# Out:
# <!DOCTYPE html>
#
# <html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-n-head-ssr="" lang="en">
# <img class="largestImage" height="99998" src="data:image/svg+xml;base64,..." style="pointer-events:none;position:absolute;top:0;left:0;width:98vw;height:99vh;max-width:98vw;max-height:99vh" width="99988"/>
# <head>
# ...

# %%
task_html.findAll("div", {"class" : "col-md-3 col-sm-6 col-xs-6 col-6 new-class"})
# Out:
# [<div class="col-md-3 col-sm-6 col-xs-6 col-6 new-class" data-v-39828e9b=""><!-- --> <div class="slide-box" data-v-39828e9b=""><div class="product-box" data-v-39828e9b=""><!-- --> <div class="view-detail" data-v-39828e9b=""><a class="view_detail_btn" data-v-39828e9b="" href="/product/highlander-men-black-white-slim-fit-casual-shirt-hlsh013904.html" id="details" target="_blank">
#                        View Detail
# ...

# %%
len(task_html.findAll("div", {"class" : "col-md-3 col-sm-6 col-xs-6 col-6 new-class"}))
# Out:
# 16

# %%
big_boxes = task_html.findAll("div", {"class" : "col-md-3 col-sm-6 col-xs-6 col-6 new-class"})

# %%
big_boxes[0]
# Out:
# <div class="col-md-3 col-sm-6 col-xs-6 col-6 new-class" data-v-39828e9b=""><!-- --> <div class="slide-box" data-v-39828e9b=""><div class="product-box" data-v-39828e9b=""><!-- --> <div class="view-detail" data-v-39828e9b=""><a class="view_detail_btn" data-v-39828e9b="" href="/product/highlander-men-black-white-slim-fit-casual-shirt-hlsh013904.html" id="details" target="_blank">
#                       View Detail
# ...

# %%
box = big_boxes[0]

# %%
box.div.div.a['href']
# Out:
# '/product/highlander-men-black-white-slim-fit-casual-shirt-hlsh013904.html'

# %%
product_link = "https://www.getketch.com/" + box.div.div.a['href']

# %%
product_link
# Out:
# 'https://www.getketch.com//product/highlander-men-black-white-slim-fit-casual-shirt-hlsh013904.html'

# %%
product_Res = requests.get(product_link)

# %%
product_Res
# Out:
# <Response [200]>

# %%
product_Res.encoding = 'utf-8'

# %%
prod_html = bs(product_Res.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
#
# <html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-n-head-ssr="" lang="en">
# <img class="largestImage" height="99998" src="data:image/svg+xml;base64,..." style="pointer-events:none;position:absolute;top:0;left:0;width:98vw;height:99vh;max-width:98vw;max-height:99vh" width="99988"/>
# <head>
# ...

# %%
details = prod_html.findAll("div", {"class" : "col-md-5 col-sm-12 content-section pdp__maininfo"})

# %%
details
# Out:
# [<div class="col-md-5 col-sm-12 content-section pdp__maininfo" data-v-247596b4=""><h2 class="font-bold brand_name" data-v-247596b4="">Highlander</h2> <h1 class="page-title" data-v-247596b4="">Highlander Men Black/White Slim Fit Casual Shirt</h1> <div class="price" data-v-247596b4=""><p data-v-247596b4=""><span class="price font-medium pr-2" data-v-247596b4="">Rs. 791</span><span class="old-price" data-v-247596b4="">Rs. 1649</span> <span class="discount_percent" data-v-247596b4="">(52%
# ...

# %%
len(details)
# Out:
# 1

# %%
details[0]
# Out:
# <div class="col-md-5 col-sm-12 content-section pdp__maininfo" data-v-247596b4=""><h2 class="font-bold brand_name" data-v-247596b4="">Highlander</h2> <h1 class="page-title" data-v-247596b4="">Highlander Men Black/White Slim Fit Casual Shirt</h1> <div class="price" data-v-247596b4=""><p data-v-247596b4=""><span class="price font-medium pr-2" data-v-247596b4="">Rs. 791</span><span class="old-price" data-v-247596b4="">Rs. 1649</span> <span class="discount_percent" data-v-247596b4="">(52%
# ...

# %%
# Extracting the Brand name title
details[0].h2
# Out:
# <h2 class="font-bold brand_name" data-v-247596b4="">Highlander</h2>

# %%
details[0].h2.text
# Out:
# 'Highlander'

# %%
# Extracting The Title

details[0].h1
# Out:
# <h1 class="page-title" data-v-247596b4="">Highlander Men Black/White Slim Fit Casual Shirt</h1>

# %%
details[0].h1.text
# Out:
# 'Highlander Men Black/White Slim Fit Casual Shirt'

# %%
# Extracting the Price

details[0].div.p.span.text
# Out:
# 'Rs. 791'

# %%
for i in details:
    print(details[0].h2.text)
    print(details[0].h1.text)
    print(details[0].div.p.span.text)
# Out:
# Highlander
# Highlander Men Black/White Slim Fit Casual Shirt
# Rs. 791

# %%
# Extracting the Best Offers

best_price  = prod_html.findAll("div", {"class" : "pdp-offers-container"})

# %%
best_price
# Out:
# [<div class="pdp-offers-container" data-v-247596b4=""><h4 data-v-247596b4="">
#              BEST OFFERS<img class="best-offer" data-v-247596b4="" src="/_nuxt/img/tag1.53eda80.png"/><!-- --></h4> <div data-v-247596b4=""><div class="pdp-offers-offer" data-v-247596b4=""><div data-v-247596b4=""><div class="pdp-offers-offerTitle" data-v-247596b4=""><b data-v-247596b4="">Best Price:
#                      <span class="pdp-offers-price" data-v-247596b4="">Rs. 751</span></b></div> <ul class="pdp-offers-offerDesc" data-v-247596b4=""><li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
#                        Applicable on:
#                        <span data-v-247596b4="">Shop for 1299 or more and get an extra 5% off, Valid on First Order</span></div></li> <li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
# ...

# %%
len(best_price)
# Out:
# 1

# %%
best_price[0].h4
# Out:
# <h4 data-v-247596b4="">
#             BEST OFFERS<img class="best-offer" data-v-247596b4="" src="/_nuxt/img/tag1.53eda80.png"/><!-- --></h4>

# %%
best_price[0].h4.text
# Out:
# '\n            BEST OFFERS'

# %%
best_price[0].div
# Out:
# <div data-v-247596b4=""><div class="pdp-offers-offer" data-v-247596b4=""><div data-v-247596b4=""><div class="pdp-offers-offerTitle" data-v-247596b4=""><b data-v-247596b4="">Best Price:
#                     <span class="pdp-offers-price" data-v-247596b4="">Rs. 751</span></b></div> <ul class="pdp-offers-offerDesc" data-v-247596b4=""><li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
#                       Applicable on:
#                       <span data-v-247596b4="">Shop for 1299 or more and get an extra 5% off, Valid on First Order</span></div></li> <li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
#                       Additional Coupon Discount
# ...

# %%
best_price[0].div.div
# Out:
# <div class="pdp-offers-offer" data-v-247596b4=""><div data-v-247596b4=""><div class="pdp-offers-offerTitle" data-v-247596b4=""><b data-v-247596b4="">Best Price:
#                     <span class="pdp-offers-price" data-v-247596b4="">Rs. 751</span></b></div> <ul class="pdp-offers-offerDesc" data-v-247596b4=""><li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
#                       Applicable on:
#                       <span data-v-247596b4="">Shop for 1299 or more and get an extra 5% off, Valid on First Order</span></div></li> <li data-v-247596b4=""><div class="pdp-offers-bullet" data-v-247596b4=""></div> <div class="pdp-offers-labelMarkup" data-v-247596b4="">
#                       Additional Coupon Discount
# ...

# %%
best_price[0].div.div.div.div.text.replace("\n                  ", "")
# Out:
# 'Best Price:  Rs. 751'

# %%
best_price[0].div.div.div.ul.text.replace("\n                  ", "")
# Out:
# '     Applicable on:    Shop for 1299 or more and get an extra 5% off, Valid on First Order      Additional Coupon Discount    5% OFF      Coupon code:    Welcome5'

# %%
best_price[0].div.div.div.ul.li.text
# Out:
# ' \n                      Applicable on:\n                      Shop for 1299 or more and get an extra 5% off, Valid on First Order'

# %%
len(best_price[0].findAll("div", {"class" : "pdp-offers-offerDesc"}))
# Out:
# 0

# %%
best_price[0].findAll("div", {"class" : "pdp-offers-offerDesc"})
# Out:
# []

# %%
for i in x:
    print(x[0].text)
# Out:
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
#                       Shop for 1299 or more and get an extra 5% off, Valid on First Order
#
#                       Applicable on:
# ...
