# %% [raw]
# TASKS
#
# 1. Go to a website
# 2. Search For a Particular product
# 3. Try to Locate Review part
# 4. Scrap all the data in local system

# %%
# Imports

from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "camera"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=camera'

# %%
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage=uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras-accessories/pr?sid=jek&amp;q=camera&amp;otracker=categorytree" title="Cameras &amp; Accessories">Cameras &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/camer
# ...

# %%
len(flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"}))
# Out:
# 29

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
for i in bigboxes:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras-accessories/pr?sid=jek&amp;q=camera&amp;otracker=categorytree" title="Cameras &amp; Accessories">Cameras &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/camera
# ...

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/cameras-accessories/pr?sid=jek&amp;q=camera&amp;otracker=categorytree" title="Cameras &amp; Accessories">Cameras &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73 _2tTQHw" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3iSBSZ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/camera
# ...

# %%
del bigboxes[0:4]

# %%
box = bigboxes[0]

# %%
box.div.div.div.a['href']
# Out:
# '/canon-eos-200d-ii-dslr-camera-ef-s18-55mm-stm/p/itm5d6e44f7fd976?pid=DLLFFNVDYGQN9XCS&lid=LSTDLLFFNVDYGQN9XCSYTRJDH&marketplace=FLIPKART&q=camera&store=jek%2Fp31&srno=s_1_4&otracker=search&fm=organic&iid=d7977de4-328d-49d0-b067-ddd530f6088f.DLLFFNVDYGQN9XCS.SEARCH&ppt=None&ppn=None&ssid=tz8jyeyiq80000001664688231428&qH=dd6d2dcc679d12b9'

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/canon-eos-200d-ii-dslr-camera-ef-s18-55mm-stm/p/itm5d6e44f7fd976?pid=DLLFFNVDYGQN9XCS&lid=LSTDLLFFNVDYGQN9XCSYTRJDH&marketplace=FLIPKART&q=camera&store=jek%2Fp31&srno=s_1_4&otracker=search&fm=organic&iid=d7977de4-328d-49d0-b067-ddd530f6088f.DLLFFNVDYGQN9XCS.SEARCH&ppt=None&ppn=None&ssid=tz8jyeyiq80000001664688231428&qH=dd6d2dcc679d12b9'

# %%
prodRes = requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding = 'utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.findAll("div", {"class" : "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Satisfied..! <br>Best mid range camera for beginners and pros as well.<br/><br/>I attached some pics shot by 50mm 1.8 prime  lens <br/>Best for photo and video as well .<br/>Eye autofocus works well .</br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_3646b4190f504be8a00d37753eab5c9d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_1cda5c1baad34db683c89e9df78b4f3b.jpg?q=90), url(data:image/svg+xml;base64,..
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
commentboxes[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Satisfied..! <br>Best mid range camera for beginners and pros as well.<br/><br/>I attached some pics shot by 50mm 1.8 prime  lens <br/>Best for photo and video as well .<br/>Eye autofocus works well .</br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_3646b4190f504be8a00d37753eab5c9d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_1cda5c1baad34db683c89e9df78b4f3b.jpg?q=90), url(data:image/svg+xml;base64,...
# ...

# %%
commentboxes[0].div
# Out:
# <div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Satisfied..! <br>Best mid range camera for beginners and pros as well.<br/><br/>I attached some pics shot by 50mm 1.8 prime  lens <br/>Best for photo and video as well .<br/>Eye autofocus works well .</br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_3646b4190f504be8a00d37753eab5c9d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_1cda5c1baad34db683c89e9df78b4f3b.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:6
# ...

# %%
commentboxes[0].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Satisfied..! <br>Best mid range camera for beginners and pros as well.<br/><br/>I attached some pics shot by 50mm 1.8 prime  lens <br/>Best for photo and video as well .<br/>Eye autofocus works well .</br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_3646b4190f504be8a00d37753eab5c9d.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202107/blobio-imr-202107_1cda5c1baad34db683c89e9df78b4f3b.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div c
# ...

# %%
commentboxes[0].div.div.find_all("div",{"class" : "t-ZTKy"})
# Out:
# [<div class="t-ZTKy"><div><div class="">Satisfied..! <br>Best mid range camera for beginners and pros as well.<br/><br/>I attached some pics shot by 50mm 1.8 prime  lens <br/>Best for photo and video as well .<br/>Eye autofocus works well .</br></div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>]

# %%
#Extracting the Commentor Review
commentboxes[0].div.div.find_all("div",{"class" : "t-ZTKy"})[0].text
# Out:
# 'Satisfied..! Best mid range camera for beginners and pros as well.I attached some pics shot by 50mm 1.8 prime  lens Best for photo and video as well .Eye autofocus works well .READ MORE'

# %%
commentboxes[0].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>]

# %%
# Extracting the person name
commentboxes[0].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Flipkart Customer'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all("div",{"class" : "t-ZTKy"})[0].text, "\n")
# Out:
# Satisfied..! Best mid range camera for beginners and pros as well.I attached some pics shot by 50mm 1.8 prime  lens Best for photo and video as well .Eye autofocus works well .READ MORE
#
# This is awesome for the beginners and very optic to use and smooth photography with much clearances. I love this 200d mark ll and best choice to learn photography.READ MORE
#
# Bought this DSLR on Big billion sale. Very happy with the performence through 18-55 stm lens. Some sample photos which I have transferred to my mobile, are attached here. I am extremely happy with its low light performance. All the photos here are unedited. I was bit confused between M50 and 200d mark II but atlast choosed the later one for its wide variety of lens options.READ MORE
#
# Absolutely brilliant camera!!Got it in a very good deal and this is my first DSLR camera. Very much impressed with the features and camera👌🏻 very good camera for all the beginnersREAD MORE
#
# ...

# %%
for i in range(len(commentboxes)-1):
    print("--", commentboxes[i].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text, "\n\n")
# Out:
# -- Flipkart Customer
#
#
# -- Antony  Dinesh
#
#
# -- SNEHASIS KARMAKAR
#
#
# -- Avinash Sonu
#
#
# -- Krishna Gupta
#
#
# -- Sayan Mukhopadhyay
#
#
# -- Moin  Pathan
#
#
# -- Sharath Chandra
#
#
# -- renju mohanlal
#
#
# -- Sharanabasava Muddalagundi

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all("div",{"class" : "t-ZTKy"})[0].text)
    print("--", commentboxes[i].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text, "\n\n")
# Out:
# Satisfied..! Best mid range camera for beginners and pros as well.I attached some pics shot by 50mm 1.8 prime  lens Best for photo and video as well .Eye autofocus works well .READ MORE
# -- Flipkart Customer
#
#
# This is awesome for the beginners and very optic to use and smooth photography with much clearances. I love this 200d mark ll and best choice to learn photography.READ MORE
# -- Antony  Dinesh
#
#
# Bought this DSLR on Big billion sale. Very happy with the performence through 18-55 stm lens. Some sample photos which I have transferred to my mobile, are attached here. I am extremely happy with its low light performance. All the photos here are unedited. I was bit confused between M50 and 200d mark II but atlast choosed the later one for its wide variety of lens options.READ MORE
# -- SNEHASIS KARMAKAR
#
#
# ...

# %%
type(commentboxes)
# Out:
# bs4.element.ResultSet

# %%
commentboxes[0].div.div.div
# Out:
# <div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div>

# %%
#commentboxes[0].div.div.div.find_all("div", {"class" : "_3LWZlK _1BLPMq"})[0].text
commentboxes[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.div.text, "\n")
# Out:
# 5
#
# 5
#
# 5
#
# 5
#
# 5
#
# 5
#
# 5
#
# 4
#
# 5
#
# 5

# %%
commentboxes[0].div.div.div.p.text
# Out:
# 'Super!'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.p.text,"\n")
# Out:
# Super!
#
# Just wow!
#
# Must buy!
#
# Wonderful
#
# Mind-blowing purchase
#
# Brilliant
#
# Must buy!
#
# Really Nice
#
# Just wow!
#
# Super!

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.p.text)
    #print(commentboxes[i].div.div.find_all("div",{"class" : "t-ZTKy"})[0].text[0:-9])
    comtag = commentboxes[i].div.div.find_all('div', {'class' : ''})
    print(comtag[0].div.text)
    print(commentboxes[i].div.div.div.div.text)
    print("--", commentboxes[i].div.div.find_all("p", {"class" : "_2sc7ZR _2V5EHH"})[0].text, "\n\n")
# Out:
# Super!
# Satisfied..! Best mid range camera for beginners and pros as well.I attached some pics shot by 50mm 1.8 prime  lens Best for photo and video as well .Eye autofocus works well .
# 5
# -- Flipkart Customer
#
#
# Just wow!
# This is awesome for the beginners and very optic to use and smooth photography with much clearances. I love this 200d mark ll and best choice to learn photography.
# 5
# -- Antony  Dinesh
#
#
# Must buy!
# Bought this DSLR on Big billion sale. Very happy with the performence through 18-55 stm lens. Some sample photos which I have transferred to my mobile, are attached here. I am extremely happy with its low light performance. All the photos here are unedited. I was bit confused between M50 and 200d mark II but atlast choosed the later one for its wide variety of lens options.
# 5
# -- SNEHASIS KARMAKAR
#
#
# Wonderful
# ...

# %% [raw]
# TASK
#
# 1. Go to ineuron.ai website
# 2. list down all the courses
# 3. one by one scrap all the courses in courses page
# 4. collect all the data segment wise
# 5. store this data in mysql/mongodb system
# 6. Deploy it on Heroku/ AWS/ GCP
# 7. Share a deployed link
# 8. Create a UI and Showcase html
#
# Restrictions
#
# 1. Don't take help from ineuron from ineuron
# 2. Always use coding standards

# %%
task_url = "https://www.ajio.com/s/clothing-4461-74582"

# %%
task_url
# Out:
# 'https://www.ajio.com/s/clothing-4461-74582'

# %%
uClient = uReq(task_url)

# %%
uClient

# %%
taskPage = uClient.read()

# %%
taskPage
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n    <head>\r\n      <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n      <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n      <meta name="format-detection" content="telephone=no" />\r\n      <meta charset="utf-8" />\r\n      <meta name = "google-site-verification" content ="mst3EDdpHbIKH409fDtfXk-wS6DAbcyLv-BXDg55gfo"/>\r\n      <meta http-equiv="Cache-control" content="no-transform">\r\n      <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no"/>\r\n      <meta name="author" content="">\r\n        \r\n        <meta name="og:type" content="website">\r\n        <meta name="og:site_name" content="Ajio.com">\r\n        <meta name="fb:app_id" content="233163173739076">\r\n        <meta name="twitter:card" content="summary">\r\n        <meta name="twitter:site" content="@AJIOLife">\r\n        \r\n        \r\n          <meta name="description" content="Buy online at Clothi
# ...

# %%
uClient.close()

# %%
task_html = bs(taskPage, "html.parser")

# %%
task_html
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection">
# <meta charset="utf-8">
# <meta content="mst3EDdpHbIKH409fDtfXk-wS6DAbcyLv-BXDg55gfo" name="google-site-verification"/>
# <meta content="no-transform" http-equiv="Cache-control"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport">
# <meta content="" name="author"/>
# <meta content="website" name="og:type"/>
# <meta content="Ajio.com" name="og:site_name"/>
# <meta content="233163173739076" name="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@AJIOLife" name="twitter:site"/>
# <meta content="Buy online at Clothing. Huge footwear and Clothing range. Order now and avail Best Discounts, Cash on Delivery, Easy Returns and Exchange." name="description"/>
# ...

# %%
task_html.findAll("div", {"class" : "item rilrtl-products-list__item item"})
# Out:
# []

# %%
len(task_html.findAll("div", {"class" : "item rilrtl-products-list__item item"}))
# Out:
# 0

# %%
big_boxes = task_html.findAll("li", {"class" : "ProductOfferingCard css-wo777h"})

# %%
for i in big_boxes:
    print(i)
# Out:
# <li class="ProductOfferingCard css-wo777h" data-test="ProductOfferingCard"><div><a aria-label="IBM Data Science Professional Certificate Offered by IBM Skills Network. Duration 3 months at 12 hours per week. Prepare for an entry-level job as a data scientist.. programDeadline. Go to certificate" class="css-jjyq8a" data-click-key="program_hub.product_variant_hub.click.product_card" data-click-value='{"entityId":"ibm-data-science","entityIndex":1,"href":"/professional-certificates/ibm-data-science","namespace":{"action":"click","app":"program_hub","component":"product_card","page":"product_variant_hub"},"schema_type":"FRONTEND"}' data-test="product-card" data-track="true" data-track-action="click" data-track-app="program_hub" data-track-component="product_card" data-track-href="/professional-certificates/ibm-data-science" data-track-page="product_variant_hub" href="/professional-certificates/ibm-data-science" to="/professional-certificates/ibm-data-science"><div class="cds-63 css-0 cds
# ...

# %%
big_boxes[0]
# Out:
# <li class="ProductOfferingCard css-wo777h" data-test="ProductOfferingCard"><div><a aria-label="IBM Data Science Professional Certificate Offered by IBM Skills Network. Duration 3 months at 12 hours per week. Prepare for an entry-level job as a data scientist.. programDeadline. Go to certificate" class="css-jjyq8a" data-click-key="program_hub.product_variant_hub.click.product_card" data-click-value='{"entityId":"ibm-data-science","entityIndex":1,"href":"/professional-certificates/ibm-data-science","namespace":{"action":"click","app":"program_hub","component":"product_card","page":"product_variant_hub"},"schema_type":"FRONTEND"}' data-test="product-card" data-track="true" data-track-action="click" data-track-app="program_hub" data-track-component="product_card" data-track-href="/professional-certificates/ibm-data-science" data-track-page="product_variant_hub" href="/professional-certificates/ibm-data-science" to="/professional-certificates/ibm-data-science"><div class="cds-63 css-0 cds
# ...

# %%
box = big_boxes[0]

# %%
box
# Out:
# <li class="ProductOfferingCard css-wo777h" data-test="ProductOfferingCard"><div><a aria-label="IBM Data Science Professional Certificate Offered by IBM Skills Network. Duration 3 months at 12 hours per week. Prepare for an entry-level job as a data scientist.. programDeadline. Go to certificate" class="css-jjyq8a" data-click-key="program_hub.product_variant_hub.click.product_card" data-click-value='{"entityId":"ibm-data-science","entityIndex":1,"href":"/professional-certificates/ibm-data-science","namespace":{"action":"click","app":"program_hub","component":"product_card","page":"product_variant_hub"},"schema_type":"FRONTEND"}' data-test="product-card" data-track="true" data-track-action="click" data-track-app="program_hub" data-track-component="product_card" data-track-href="/professional-certificates/ibm-data-science" data-track-page="product_variant_hub" href="/professional-certificates/ibm-data-science" to="/professional-certificates/ibm-data-science"><div class="cds-63 css-0 cds
# ...

# %%
box.div.a['href']
# Out:
# '/professional-certificates/ibm-data-science'

# %%
product_link = "https://www.coursera.com" + box.div.a['href']

# %%
product_link
# Out:
# 'https://www.coursera.com/professional-certificates/ibm-data-science'
